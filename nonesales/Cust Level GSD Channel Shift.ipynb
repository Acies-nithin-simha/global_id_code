# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.float_format','{:.2f}'.format)

# %%
tp_12_1 = '24_jun_12'
tp_12_2 = '25_jun_12'
tp_9_1 = '24_jun_9'
tp_9_2 = '25_jun_9'

# %%
usag_3  = pd.read_parquet(f"Outputs/usag_diff_{tp_9_2}_{tp_12_2}_bucket_isocos_pneinc_updated.parquet")

# %%
# usag_3['macs_id'] = usag_3['global_id'].str.extract(r'^([A-Z]{2,3}\d{3})')

# %%
usag_3
# Out:
#                                     global_id  flag_gl_id  \
# 0        000006c3-c93c-b2d1-75a9-d55eff943df8        0.00
# 1        000008fd-b89a-e34f-4cc1-8082184f9627        0.00
# 2        00000d0f-4cff-2258-96e3-37fb60e6dd3f        0.00
# 3        00001b6a-9f19-d466-5b17-498b2134e54b        0.00
# 4        00003208-43d2-548e-6834-1d26ca82306f        0.00
# ...                                       ...         ...
# 1698982  ffffe0b8-4419-19cc-ebca-e9f175b9a7b3        0.00
# 1698983  ffffebc6-2076-9b23-51c2-5f5293338412        0.00
# 1698984  fffff3c4-c07a-8d6a-8d98-a74f28d06baf        0.00
# 1698985  fffffc8f-cb07-b227-ef84-b2b43815c1ff        0.00
# 1698986  fffffd91-46e2-20ea-7190-1f2775e09e28        0.00
#
#          24_jun_9_Total_esales  24_jun_9_Total_nonesales  \
# 0                         0.00                    358.79
# 1                         0.00                   1120.85
# 2                         0.00                   2276.41
# 3                      1215.23                   6804.77
# 4                         0.00                      0.00
# ...                        ...                       ...
# 1698982                   0.00                     85.47
# 1698983                   0.00                      0.00
# 1698984                   0.00                      0.00
# 1698985                   0.00                      0.00
# 1698986                   0.00                      0.00
#
#          24_jun_12_Total_esales  24_jun_12_Total_nonesales  \
# 0                          0.00                     687.04
# 1                          0.00                    1171.71
# 2                          0.00                    3792.03
# 3                       1903.89                    6654.78
# 4                          0.00                       0.00
# ...                         ...                        ...
# 1698982                    0.00                      85.47
# 1698983                    0.00                       0.00
# 1698984                    0.00                       0.00
# 1698985                    0.00                       0.00
# 1698986                    0.00                       0.00
#
#          25_jun_9_Total_esales  25_jun_9_Total_nonesales  \
# 0                         0.00                   1740.77
# 1                         0.00                   1193.36
# 2                         0.00                   2367.23
# 3                         0.00                    129.90
# 4                         0.00                      0.00
# ...                        ...                       ...
# 1698982                   0.00                      0.00
# 1698983                   0.00                    108.71
# 1698984                   0.00                    204.12
# 1698985                   0.00                    330.65
# 1698986                   0.00                      0.00
#
#          24_jun_9_25_jun_9_nonesales_incremental_abs  25_jun_12_Total_esales  \
# 0                                            1155.79                    0.00
# 1                                             126.77                    0.00
# 2                                             201.01                  226.26
# 3                                           -5918.35                    0.00
# 4                                               0.00                    0.00
# ...                                              ...                     ...
# 1698982                                      -139.35                    0.00
# 1698983                                         0.00                    0.00
# 1698984                                         0.00                    0.00
# 1698985                                         0.00                    0.00
# 1698986                                         0.00                    0.00
#
#          ...  24_jun_12_25_jun_12_act_mon_esales_sd_1_segment  \
# 0        ...                                   Not in Channel
# 1        ...                                   Not in Channel
# 2        ...                                              New
# 3        ...                                        Declining
# 4        ...                                   Not in Channel
# ...      ...                                              ...
# 1698982  ...                                   Not in Channel
# 1698983  ...                                   Not in Channel
# 1698984  ...                                   Not in Channel
# 1698985  ...                                   Not in Channel
# 1698986  ...                                   Not in Channel
#
#          24_jun_12_25_jun_12_act_mon_nonesales_sd_1_segment 24_jun_12_bucket  \
# 0                                                  Growing          500-1000
# 1                                                   Stable         1000-2500
# 2                                                   Stable         2500-5000
# 3                                                   Stable        5000-10000
# 4                                           Not in Channel                 0
# ...                                                    ...               ...
# 1698982                                          Declining             0-500
# 1698983                                                New                 0
# 1698984                                                New                 0
# 1698985                                                New                 0
# 1698986                                     Not in Channel                 0
#
#         diff_Total_esales_curr diff_Total_nonesales_curr  \
# 0                         0.00                    606.15
# 1                         0.00                     77.00
# 2                       226.26                    617.67
# 3                         0.00                     79.99
# 4                         0.00                      0.00
# ...                        ...                       ...
# 1698982                   0.00                      0.00
# 1698983                   0.00                    171.46
# 1698984                   0.00                      0.00
# 1698985                   0.00                      0.00
# 1698986                   0.00                      0.00
#
#          diff_Total_esales_prev  diff_Total_nonesales_prev  \
# 0                          0.00                     328.25
# 1                          0.00                      50.86
# 2                          0.00                    1515.62
# 3                        688.66                    -149.99
# 4                          0.00                       0.00
# ...                         ...                        ...
# 1698982                    0.00                       0.00
# 1698983                    0.00                       0.00
# 1698984                    0.00                       0.00
# 1698985                    0.00                       0.00
# 1698986                    0.00                       0.00
#
#          diff_nonesales_incremental_abs_updated  \
# 0                                        417.85
# 1                                        -22.58
# 2                                       -731.78
# 3                                         83.93
# 4                                          0.00
# ...                                         ...
# 1698982                                   -5.53
# 1698983                                    0.00
# 1698984                                    0.00
# 1698985                                    0.00
# 1698986                                    0.00
#
#          25_jun_9_25_jun_12_act_mon_esales_sd_1_segment  \
# 0                                        Not in Channel
# 1                                        Not in Channel
# 2                                                   New
# 3                                             Declining
# 4                                        Not in Channel
# ...                                                 ...
# 1698982                                  Not in Channel
# 1698983                                  Not in Channel
# 1698984                                  Not in Channel
# 1698985                                  Not in Channel
# 1698986                                  Not in Channel
#
#          25_jun_9_25_jun_12_act_mon_nonesales_sd_1_segment
# 0                                                  Growing
# 1                                                   Stable
# 2                                                   Stable
# 3                                                   Stable
# 4                                           Not in Channel
# ...                                                    ...
# 1698982                                          Declining
# 1698983                                                New
# 1698984                                                New
# 1698985                                                New
# 1698986                                     Not in Channel
#
# [1698987 rows x 22 columns]

# %%
core_segments = ['Growing','Stable','Declining']

# %%
usag_3.columns
# Out:
# Index(['global_id', 'flag_gl_id', '24_jun_9_Total_esales',
#        '24_jun_9_Total_nonesales', '24_jun_12_Total_esales',
#        '24_jun_12_Total_nonesales', '25_jun_9_Total_esales',
#        '25_jun_9_Total_nonesales',
#        '24_jun_9_25_jun_9_nonesales_incremental_abs', '25_jun_12_Total_esales',
#        '25_jun_12_Total_nonesales',
#        '24_jun_12_25_jun_12_nonesales_incremental_abs',
#        '24_jun_12_25_jun_12_act_mon_esales_sd_1_segment',
#        '24_jun_12_25_jun_12_act_mon_nonesales_sd_1_segment',
#        '24_jun_12_bucket', 'diff_Total_esales_curr',
#        'diff_Total_nonesales_curr', 'diff_Total_esales_prev',
#        'diff_Total_nonesales_prev', 'diff_nonesales_incremental_abs_updated',
#        '25_jun_9_25_jun_12_act_mon_esales_sd_1_segment',
#        '25_jun_9_25_jun_12_act_mon_nonesales_sd_1_segment'],
#       dtype='object')

# %%
# usag_3.boxplot(column='diff_Total_esales_prev')

# %%
usag_df = usag_3[
    ((usag_3[f'{tp_12_1}_{tp_12_2}_act_mon_esales_sd_1_segment'].isin(core_segments)) &
     (usag_3[f'{tp_12_1}_{tp_12_2}_act_mon_nonesales_sd_1_segment'].isin(core_segments))) & 
     ~((usag_3[f'{tp_12_1}_{tp_12_2}_act_mon_esales_sd_1_segment']=='Stable') & (usag_3[f'{tp_12_1}_{tp_12_2}_act_mon_nonesales_sd_1_segment']=='Stable'))
]

# %%
usag_df
# Out:
#                                     global_id  flag_gl_id  \
# 3        00001b6a-9f19-d466-5b17-498b2134e54b        0.00
# 16       0001041f-14e6-47b6-8db8-67d6798f2ecd        0.00
# 18       000116f0-8ab3-480e-bd62-ecd5cf2a674a        0.00
# 30       0001c703-29d7-4dde-827a-8a657075a158        0.00
# 42       00029716-dde6-4c44-9c73-d1049559ff71        0.00
# ...                                       ...         ...
# 1698825  fff92584-ba4e-0f63-733e-f65a64e3c0a1        0.00
# 1698838  fff9bb7c-5a34-ca99-2853-cc0829b5a0d9        0.00
# 1698840  fff9c412-c03d-37d7-cd83-a8a824431f24        0.00
# 1698893  fffc02d7-1cc0-476f-a09b-0f9d64ac0588        0.00
# 1698912  fffcb0cf-fc26-6c35-17a0-8aed0bc08451        0.00
#
#          24_jun_9_Total_esales  24_jun_9_Total_nonesales  \
# 3                      1215.23                   6804.77
# 16                     5998.80                  28959.28
# 18                     1347.59                   3412.17
# 30                     1413.61                  48321.43
# 42                      145.85                    120.04
# ...                        ...                       ...
# 1698825                 500.00                   -500.00
# 1698838                  36.38                    150.19
# 1698840                   0.00                  11522.13
# 1698893               33832.59                   -555.18
# 1698912                 218.19                  50188.71
#
#          24_jun_12_Total_esales  24_jun_12_Total_nonesales  \
# 3                       1903.89                    6654.78
# 16                      7219.31                   38638.79
# 18                      1883.04                    4233.28
# 30                      7708.16                   62226.00
# 42                       145.85                     277.14
# ...                         ...                        ...
# 1698825                  500.00                    -500.00
# 1698838                  219.20                     272.96
# 1698840                  679.75                   14297.15
# 1698893                33832.59                    -555.18
# 1698912                  218.19                   68017.66
#
#          25_jun_9_Total_esales  25_jun_9_Total_nonesales  \
# 3                         0.00                    129.90
# 16                     2213.09                   7864.63
# 18                     3299.43                    682.22
# 30                     7910.54                  32557.28
# 42                        0.00                     39.95
# ...                        ...                       ...
# 1698825                   0.00                      0.00
# 1698838                1848.11                    273.24
# 1698840                2515.15                  16652.00
# 1698893                   0.00                     81.60
# 1698912                   0.00                  49581.86
#
#          24_jun_9_25_jun_9_nonesales_incremental_abs  25_jun_12_Total_esales  \
# 3                                           -5918.35                    0.00
# 16                                         -18302.23                 4710.01
# 18                                          -2417.71                 6079.72
# 30                                         -11104.73                30251.88
# 42                                           -155.77                    0.00
# ...                                              ...                     ...
# 1698825                                        -0.00                    0.00
# 1698838                                        28.37                 2287.72
# 1698840                                      6683.48                 3170.68
# 1698893                                      -555.18                    0.00
# 1698912                                      4232.63                    0.00
#
#          ...  24_jun_12_25_jun_12_act_mon_esales_sd_1_segment  \
# 3        ...                                        Declining
# 16       ...                                           Stable
# 18       ...                                          Growing
# 30       ...                                          Growing
# 42       ...                                        Declining
# ...      ...                                              ...
# 1698825  ...                                        Declining
# 1698838  ...                                          Growing
# 1698840  ...                                           Stable
# 1698893  ...                                        Declining
# 1698912  ...                                        Declining
#
#          24_jun_12_25_jun_12_act_mon_nonesales_sd_1_segment 24_jun_12_bucket  \
# 3                                                   Stable        5000-10000
# 16                                               Declining            25000+
# 18                                                  Stable         2500-5000
# 30                                                  Stable            25000+
# 42                                                  Stable             0-500
# ...                                                    ...               ...
# 1698825                                          Declining                <0
# 1698838                                             Stable             0-500
# 1698840                                            Growing       10000-25000
# 1698893                                             Stable                <0
# 1698912                                             Stable            25000+
#
#         diff_Total_esales_curr diff_Total_nonesales_curr  \
# 3                         0.00                     79.99
# 16                     2496.92                   7496.09
# 18                     2780.29                   1552.58
# 30                    22341.34                  19370.48
# 42                        0.00                      0.00
# ...                        ...                       ...
# 1698825                   0.00                      0.00
# 1698838                 439.61                    122.68
# 1698840                 655.53                  11079.89
# 1698893                   0.00                      0.00
# 1698912                   0.00                  19600.36
#
#          diff_Total_esales_prev  diff_Total_nonesales_prev  \
# 3                        688.66                    -149.99
# 16                      1220.51                    9679.51
# 18                       535.45                     821.11
# 30                      6294.55                   13904.57
# 42                         0.00                     157.10
# ...                         ...                        ...
# 1698825                    0.00                       0.00
# 1698838                  182.82                     122.77
# 1698840                  679.75                    2775.02
# 1698893                    0.00                       0.00
# 1698912                    0.00                   17828.95
#
#          diff_nonesales_incremental_abs_updated  \
# 3                                         83.93
# 16                                     -1632.66
# 18                                       727.75
# 30                                      6190.51
# 42                                      -274.08
# ...                                         ...
# 1698825                                    0.00
# 1698838                                  -95.15
# 1698840                                 8347.85
# 1698893                                    0.00
# 1698912                                 2817.07
#
#          25_jun_9_25_jun_12_act_mon_esales_sd_1_segment  \
# 3                                             Declining
# 16                                               Stable
# 18                                              Growing
# 30                                              Growing
# 42                                            Declining
# ...                                                 ...
# 1698825                                       Declining
# 1698838                                         Growing
# 1698840                                          Stable
# 1698893                                       Declining
# 1698912                                       Declining
#
#          25_jun_9_25_jun_12_act_mon_nonesales_sd_1_segment
# 3                                                   Stable
# 16                                               Declining
# 18                                                  Stable
# 30                                                  Stable
# 42                                                  Stable
# ...                                                    ...
# 1698825                                          Declining
# 1698838                                             Stable
# 1698840                                            Growing
# 1698893                                             Stable
# 1698912                                             Stable
#
# [61374 rows x 22 columns]

# %%
usag_df['diff_nonesales_incremental_abs_updated'].sum()
# Out:
# np.float64(1152549.6460808953)

# %%
# usag_df.to_excel('GSD Data.xlsx')

# %%
def seg_num(df,tp_12_1,tp_12_2,core_segments):
    e_seg = f'{tp_12_1}_{tp_12_2}_act_mon_esales_sd_1_segment'
    n_seg = f'{tp_12_1}_{tp_12_2}_act_mon_nonesales_sd_1_segment'
    
    cond = [
        (df[e_seg] == seg1) & (df[n_seg] == seg2)
        for seg1 in core_segments for seg2 in core_segments
    ]

    choices = [num for num in range(1,10)]

    return np.select(cond,choices,default=0)

def channel_shift_12(df,tp_12_1,tp_12_2):
    tp1_e_total = f'{tp_12_1}_Total_esales'
    tp1_n_total = f'{tp_12_1}_Total_nonesales'
    seg_nums_not_included = [2,4,5,6,8,9]
    
    cond1 = (df[tp1_e_total] + df[tp1_n_total] < 1) | (df['seg_num'].isin(seg_nums_not_included))
    cond2 = ((df['diff_12_esales'] < 0) & (df['diff_12_nonesales'] < 0)) | ((df['diff_12_esales'] > 0) & (df['diff_12_nonesales'] > 0) & (df['diff_12_esales'] < df['diff_12_nonesales'])) 

    cond = [cond1, cond2]

    choices = ['Not Considered','No Channel Shift']

    return np.select(cond, choices, default='Channel Shift')

def channel_shift_9(df,tp_9_1,tp_9_2):
    tp1_e_total = f'{tp_9_1}_Total_esales'
    tp1_n_total = f'{tp_9_1}_Total_nonesales'
    seg_nums_not_included = [2,4,5,6,8,9]
    
    cond1 = (df[tp1_e_total] + df[tp1_n_total] < 1) | (df['seg_num'].isin(seg_nums_not_included))
    cond2 = ((df['diff_9_esales'] < 0) & (df['diff_9_nonesales'] < 0)) | ((df['diff_9_esales'] > 0) & (df['diff_9_nonesales'] > 0) & (df['diff_9_esales'] < df['diff_9_nonesales'])) 

    cond = [cond1, cond2]

    choices = ['Not Considered','No Channel Shift']

    return np.select(cond, choices, default='Channel Shift')

def compute_discount_12(df,tp_12_1):
    bucket_col = f'{tp_12_1}_bucket'
    comp_yoy_col = 'comp_bucket_YoY_12'

    conditions = [
        df[bucket_col].isin(['<0', '0'])
    ]
    
    choices = [
        0.0
    ]
    
    comp_doll = np.select(conditions, choices, default = df[comp_yoy_col] * df[f'{tp_12_1}_Total_nonesales'])
    return comp_doll

def compute_discount_9(df,tp_9_1):
    bucket_col = f'{tp_9_1}_bucket'
    comp_yoy_col = 'comp_bucket_YoY_9'

    conditions = [
        df[bucket_col].isin(['<0', '0'])
    ]
    
    choices = [
        0.0
    ]
    
    comp_doll = np.select(conditions, choices, default = df[comp_yoy_col] * df[f'{tp_9_1}_Total_nonesales'])
    return comp_doll

# %%
usag_df['diff_12_esales'] = usag_df[f'{tp_12_2}_Total_esales'] - usag_df[f'{tp_12_1}_Total_esales'] 
usag_df['diff_12_nonesales'] = usag_df[f'{tp_12_2}_Total_nonesales'] - usag_df[f'{tp_12_1}_Total_nonesales'] 

usag_df['diff_9_esales'] = usag_df[f'{tp_9_2}_Total_esales'] - usag_df[f'{tp_9_1}_Total_esales'] 
usag_df['diff_9_nonesales'] = usag_df[f'{tp_9_2}_Total_nonesales'] - usag_df[f'{tp_9_1}_Total_nonesales']
# Out:
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\203765608.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['diff_12_esales'] = usag_df[f'{tp_12_2}_Total_esales'] - usag_df[f'{tp_12_1}_Total_esales']
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\203765608.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['diff_12_nonesales'] = usag_df[f'{tp_12_2}_Total_nonesales'] - usag_df[f'{tp_12_1}_Total_nonesales']
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\203765608.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['diff_9_esales'] = usag_df[f'{tp_9_2}_Total_esales'] - usag_df[f'{tp_9_1}_Total_esales']
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\203765608.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['diff_9_nonesales'] = usag_df[f'{tp_9_2}_Total_nonesales'] - usag_df[f'{tp_9_1}_Total_nonesales']

# %%
usag_df['seg_num'] = seg_num(usag_df,tp_12_1, tp_12_2, core_segments)
# Out:
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\3853203827.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['seg_num'] = seg_num(usag_df,tp_12_1, tp_12_2, core_segments)

# %%
usag_df['Channel_Shift_Status_12'] = channel_shift_12(usag_df,tp_12_1, tp_12_2)

usag_df['Channel_Shift_Status_9'] = channel_shift_9(usag_df,tp_9_1, tp_9_2)
# Out:
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\2852971718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['Channel_Shift_Status_12'] = channel_shift_12(usag_df,tp_12_1, tp_12_2)
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\2852971718.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['Channel_Shift_Status_9'] = channel_shift_9(usag_df,tp_9_1, tp_9_2)

# %%
usag_df['nonesales_l12_12%'] = (usag_df[f'{tp_12_2}_Total_nonesales'] /( usag_df[f'{tp_12_2}_Total_esales'] + usag_df[f'{tp_12_2}_Total_nonesales'])).fillna(0)
usag_df['nonesales_l1324_12%'] = (usag_df[f'{tp_12_1}_Total_nonesales'] /( usag_df[f'{tp_12_1}_Total_esales'] + usag_df[f'{tp_12_1}_Total_nonesales'])).fillna(0)
usag_df['nonesales_tobe_12'] = ((usag_df[f'{tp_12_1}_Total_nonesales'] /( usag_df[f'{tp_12_1}_Total_esales'] + usag_df[f'{tp_12_1}_Total_nonesales'])) * ( usag_df[f'{tp_12_2}_Total_esales'] + usag_df[f'{tp_12_2}_Total_nonesales'])).fillna(0)


usag_df['nonesales_l12_9%'] = (usag_df[f'{tp_9_2}_Total_nonesales'] /( usag_df[f'{tp_9_2}_Total_esales'] + usag_df[f'{tp_9_2}_Total_nonesales'])).fillna(0)
usag_df['nonesales_l1324_9%'] = (usag_df[f'{tp_9_1}_Total_nonesales'] /( usag_df[f'{tp_9_1}_Total_esales'] + usag_df[f'{tp_9_1}_Total_nonesales'])).fillna(0)
usag_df['nonesales_tobe_9'] = ((usag_df[f'{tp_9_1}_Total_nonesales'] /( usag_df[f'{tp_9_1}_Total_esales'] + usag_df[f'{tp_9_1}_Total_nonesales'])) * ( usag_df[f'{tp_9_2}_Total_esales'] + usag_df[f'{tp_9_2}_Total_nonesales'])).fillna(0)
# Out:
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\3027167168.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['nonesales_l12_12%'] = (usag_df[f'{tp_12_2}_Total_nonesales'] /( usag_df[f'{tp_12_2}_Total_esales'] + usag_df[f'{tp_12_2}_Total_nonesales'])).fillna(0)
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\3027167168.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['nonesales_l1324_12%'] = (usag_df[f'{tp_12_1}_Total_nonesales'] /( usag_df[f'{tp_12_1}_Total_esales'] + usag_df[f'{tp_12_1}_Total_nonesales'])).fillna(0)
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\3027167168.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['nonesales_tobe_12'] = ((usag_df[f'{tp_12_1}_Total_nonesales'] /( usag_df[f'{tp_12_1}_Total_esales'] + usag_df[f'{tp_12_1}_Total_nonesales'])) * ( usag_df[f'{tp_12_2}_Total_esales'] + usag_df[f'{tp_12_2}_Total_nonesales'])).fillna(0)
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\3027167168.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['nonesales_l12_9%'] = (usag_df[f'{tp_9_2}_Total_nonesales'] /( usag_df[f'{tp_9_2}_Total_esales'] + usag_df[f'{tp_9_2}_Total_nonesales'])).fillna(0)
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\3027167168.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['nonesales_l1324_9%'] = (usag_df[f'{tp_9_1}_Total_nonesales'] /( usag_df[f'{tp_9_1}_Total_esales'] + usag_df[f'{tp_9_1}_Total_nonesales'])).fillna(0)
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\3027167168.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['nonesales_tobe_9'] = ((usag_df[f'{tp_9_1}_Total_nonesales'] /( usag_df[f'{tp_9_1}_Total_esales'] + usag_df[f'{tp_9_1}_Total_nonesales'])) * ( usag_df[f'{tp_9_2}_Total_esales'] + usag_df[f'{tp_9_2}_Total_nonesales'])).fillna(0)

# %%
usag_df['Channel_shift_tobe_12'] = np.select([(usag_df[f'{tp_12_1}_Total_esales'] + usag_df[f'{tp_12_1}_Total_nonesales'] < 1)],[0],default=(usag_df[f'{tp_12_2}_Total_nonesales'] - usag_df['nonesales_tobe_12']))

usag_df['Channel_shift_tobe_9'] = np.select([(usag_df[f'{tp_9_1}_Total_esales'] + usag_df[f'{tp_9_1}_Total_nonesales'] < 1)],[0],default=(usag_df[f'{tp_9_2}_Total_nonesales'] - usag_df['nonesales_tobe_9']))
# Out:
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\613682383.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['Channel_shift_tobe_12'] = np.select([(usag_df[f'{tp_12_1}_Total_esales'] + usag_df[f'{tp_12_1}_Total_nonesales'] < 1)],[0],default=(usag_df[f'{tp_12_2}_Total_nonesales'] - usag_df['nonesales_tobe_12']))
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\613682383.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['Channel_shift_tobe_9'] = np.select([(usag_df[f'{tp_9_1}_Total_esales'] + usag_df[f'{tp_9_1}_Total_nonesales'] < 1)],[0],default=(usag_df[f'{tp_9_2}_Total_nonesales'] - usag_df['nonesales_tobe_9']))

# %%
usag_df['Channel_Shift_value_12'] = np.select([(usag_df['Channel_Shift_Status_12']=='Channel Shift')],[(usag_df['Channel_shift_tobe_12'])],default=0)

usag_df['Channel_Shift_value_9'] = np.select([(usag_df['Channel_Shift_Status_9']=='Channel Shift')],[(usag_df['Channel_shift_tobe_9'])],default=0)
# Out:
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\3083078752.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['Channel_Shift_value_12'] = np.select([(usag_df['Channel_Shift_Status_12']=='Channel Shift')],[(usag_df['Channel_shift_tobe_12'])],default=0)
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\3083078752.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['Channel_Shift_value_9'] = np.select([(usag_df['Channel_Shift_Status_9']=='Channel Shift')],[(usag_df['Channel_shift_tobe_9'])],default=0)

# %%
usag_df['Channel_Shift_value_12'].sum()
# Out:
# np.float64(-8094111.258610986)

# %%
usag_df['Channel_Shift_value_9'].sum()
# Out:
# np.float64(-7879799.8768454855)

# %%
usag_df['Channel_Shift_Value_12-9'] = usag_df['Channel_Shift_value_12'] - usag_df['Channel_Shift_value_9']
# Out:
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\3375941977.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['Channel_Shift_Value_12-9'] = usag_df['Channel_Shift_value_12'] - usag_df['Channel_Shift_value_9']

# %%
usag_df['Channel_Shift_Value_12-9'].sum()
# Out:
# np.float64(-214311.3817655042)

# %%
usag_df['Incremental_adjusted'] = usag_df['diff_nonesales_incremental_abs_updated'] - usag_df['Channel_Shift_Value_12-9']
# Out:
# C:\Users\661827\AppData\Local\Temp\ipykernel_15140\132517982.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   usag_df['Incremental_adjusted'] = usag_df['diff_nonesales_incremental_abs_updated'] - usag_df['Channel_Shift_Value_12-9']

# %%
usag_df['Incremental_adjusted'].sum()
# Out:
# np.float64(1366861.0278464002)

# %%
usag_df.groupby('flag_gl_id')['Incremental_adjusted'].sum()
# Out:
# flag_gl_id
# 0.00    2741645.38
# 1.00   -1374784.36
# Name: Incremental_adjusted, dtype: float64

# %%
usag_df.groupby('flag_gl_id')['global_id'].count()
# Out:
# flag_gl_id
# 0.00    54909
# 1.00     6465
# Name: global_id, dtype: int64

# %%
usag_df.groupby(f'{tp_12_1}_bucket')['Incremental_adjusted'].sum()
# Out:
# 24_jun_12_bucket
# 0                   145.46
# 0-500           1402830.53
# 1000-2500       3267225.54
# 10000-25000      835379.64
# 2500-5000       3223828.56
# 25000+        -12675370.23
# 500-1000        1849494.80
# 5000-10000      3635357.01
# <0              -172030.28
# Name: Incremental_adjusted, dtype: float64

# %%
usag_df.groupby(f'{tp_12_1}_bucket')['global_id'].count()
# Out:
# 24_jun_12_bucket
# 0                 23
# 0-500          12027
# 1000-2500       9278
# 10000-25000     8938
# 2500-5000       7685
# 25000+          7700
# 500-1000        6094
# 5000-10000      7747
# <0              1882
# Name: global_id, dtype: int64

# %%
# usag_df.groupby('flag_gl_id')['macs_id'].nunique()

# %%
cross_tab_view = pd.crosstab(usag_df[f'{tp_12_1}_{tp_12_2}_act_mon_esales_sd_1_segment'],usag_df[f'{tp_12_1}_{tp_12_2}_act_mon_nonesales_sd_1_segment'],
            values=usag_df['Channel_Shift_Value_12-9'],aggfunc='sum')
cross_tab_view = cross_tab_view.reindex(index=core_segments,columns=core_segments)
cross_tab_view
# Out:
# 24_jun_12_25_jun_12_act_mon_nonesales_sd_1_segment    Growing  Stable  \
# 24_jun_12_25_jun_12_act_mon_esales_sd_1_segment
# Growing                                            1724572.94    0.00
# Stable                                                   0.00     NaN
# Declining                                          2797722.66    0.00
#
# 24_jun_12_25_jun_12_act_mon_nonesales_sd_1_segment   Declining
# 24_jun_12_25_jun_12_act_mon_esales_sd_1_segment
# Growing                                            -4736606.98
# Stable                                                    0.00
# Declining                                                 0.00

# %%
cross_tab_view2 = pd.crosstab(usag_df[f'{tp_12_1}_{tp_12_2}_act_mon_esales_sd_1_segment'],usag_df[f'{tp_12_1}_{tp_12_2}_act_mon_nonesales_sd_1_segment'],
            values=usag_df['diff_nonesales_incremental_abs_updated'],aggfunc='sum')
cross_tab_view2 = cross_tab_view2.reindex(index=core_segments,columns=core_segments)
cross_tab_view2
# Out:
# 24_jun_12_25_jun_12_act_mon_nonesales_sd_1_segment     Growing      Stable  \
# 24_jun_12_25_jun_12_act_mon_esales_sd_1_segment
# Growing                                            12682886.63 -6030706.28
# Stable                                             22273801.86         NaN
# Declining                                           6457228.85 -7765159.72
#
# 24_jun_12_25_jun_12_act_mon_nonesales_sd_1_segment    Declining
# 24_jun_12_25_jun_12_act_mon_esales_sd_1_segment
# Growing                                             -5647575.80
# Stable                                              -9380985.61
# Declining                                          -11436940.29

# %%
usag_df.to_parquet(f'Outputs/{tp_12_2} ISO COS Channel Shift Discount.parquet')

# %%
# cross_tab_view.to_excel(f'Outputs/{tp_12_2} ISO COS Channel Shift crosstab view.xlsx')

# %%
usag_df.groupby([f'{tp_12_1}_bucket','flag_gl_id'])['Incremental_adjusted'].sum().reset_index().to_excel('Inc_bucketwise.xlsx')

# %%
usag_df.groupby([f'{tp_12_1}_bucket','flag_gl_id'])['Incremental_adjusted'].sum().reset_index()
# Out:
#    24_jun_12_bucket  flag_gl_id  Incremental_adjusted
# 0                 0        0.00                 36.27
# 1                 0        1.00                109.19
# 2             0-500        0.00            1266583.25
# 3             0-500        1.00             136247.28
# 4         1000-2500        0.00            3023093.33
# 5         1000-2500        1.00             244132.21
# 6       10000-25000        0.00            1172771.49
# 7       10000-25000        1.00            -337391.85
# 8         2500-5000        0.00            2981772.77
# 9         2500-5000        1.00             242055.79
# 10           25000+        0.00          -10533478.71
# 11           25000+        1.00           -2141891.52
# 12         500-1000        0.00            1668995.18
# 13         500-1000        1.00             180499.62
# 14       5000-10000        0.00            3315134.04
# 15       5000-10000        1.00             320222.96
# 16               <0        0.00            -153262.24
# 17               <0        1.00             -18768.04

# %%
# bucket_bins = [-np.inf,0,0.001,500,1000,2500, 5000, 10000, 25000, np.inf]
# buckets = ['<0','0','0-500','500-1000','1000-2500','2500-5000', '5000-10000', '10000-25000', '25000+']

# usag_df[f'{tp_12_1}_bucket'] = pd.cut(usag_df[f'{tp_12_1}_Total_esales'], bins=bucket_bins, labels=buckets, right=False)
# usag_df[f'{tp_9_1}_bucket'] = pd.cut(usag_df[f'{tp_9_1}_Total_esales'], bins=bucket_bins, labels=buckets, right=False)

# %%
# esales_buckets_12 = usag_df.groupby(f'{tp_12_1}_bucket')[[f'{tp_12_1}_Total_esales',f'{tp_12_2}_Total_esales']].sum().reset_index()
# esales_buckets_12['comp_bucket_YoY_12'] = (esales_buckets_12[f'{tp_12_2}_Total_esales']/esales_buckets_12[f'{tp_12_1}_Total_esales'])-1
# esales_buckets_12 = esales_buckets_12[[f'{tp_12_1}_bucket','comp_bucket_YoY_12']]
# usag_df = usag_df.merge(esales_buckets_12,how='left',on=f'{tp_12_1}_bucket')
# esales_buckets_12

# %%
# esales_buckets_9 = usag_df.groupby(f'{tp_9_1}_bucket')[[f'{tp_9_1}_Total_esales',f'{tp_9_2}_Total_esales']].sum().reset_index()
# esales_buckets_9['comp_bucket_YoY_9'] = (esales_buckets_9[f'{tp_9_2}_Total_esales']/esales_buckets_9[f'{tp_9_1}_Total_esales'])-1
# esales_buckets_9 = esales_buckets_9[[f'{tp_9_1}_bucket','comp_bucket_YoY_9']]
# usag_df = usag_df.merge(esales_buckets_9,how='left',on=f'{tp_9_1}_bucket')
# esales_buckets_9

# %%
# usag_df['comp_bucket_doll_12'] = compute_discount_12(usag_df,tp_12_1)

# usag_df['comp_bucket_doll_9'] = compute_discount_9(usag_df,tp_9_1)

# %%
# usag_df['adj_tobe_12'] = usag_df['Channel_shift_tobe_12'] - usag_df['comp_bucket_doll_12']

# usag_df['adj_tobe_9'] = usag_df['Channel_shift_tobe_9'] - usag_df['comp_bucket_doll_9']

# %%
# usag_df['adj_doll_12'] = np.select([(usag_df['Channel_Shift_Status_12']=='Channel Shift')],[(usag_df['adj_tobe_12'])],default=0)

# usag_df['adj_doll_9'] = np.select([(usag_df['Channel_Shift_Status_9']=='Channel Shift')],[(usag_df['adj_tobe_9'])],default=0)

# %%
# usag_df['adj_doll_12'].sum() - usag_df['adj_doll_9'].sum()

# %%
# usag_df['adj_doll_9'].sum()

# %%
# usag_df.to_excel(f'Outputs/{tp_12_2}Channel Shift Discount.xlsx')
