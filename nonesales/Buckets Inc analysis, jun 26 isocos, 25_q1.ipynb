# %% [markdown]
# # Data Loading

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
pd.set_option('display.float_format','{:.2f}'.format)

# %%
nonesales = pd.read_parquet('../Data/nonesales_pivoted_2025_cleaned_v2.parquet')

# %%
esales = pd.read_parquet('../Data/esales_pivoted_2025_cleaned_v2.parquet')

# %%
def get_month_list(tp):
    yy, mon_str, k_str = tp.split('_')
    k = int(k_str)
    base_year = 2000 + int(yy)
    start_date = datetime.strptime(f'{mon_str}_{base_year - 1}', '%b_%Y') + relativedelta(months=1)
    return [(start_date + relativedelta(months=i)).strftime('%Y-%m') for i in range(k)]

# %% [markdown]
# # Time Level 12 months apr-24 to mar-25

# %% [markdown]
# ## Time Level Definition

# %%
tp1 = '24_jun_12'
tp2 = '25_jun_12'


tp1_cols = get_month_list(tp1)
tp2_cols = get_month_list(tp2)

# %%
esales_df = esales[['global_id','flag_gl_id'] + tp1_cols + tp2_cols]
nonesales_df = nonesales[['global_id','flag_gl_id'] + tp1_cols + tp2_cols]

# %% [markdown]
# ## Pre Analysis

# %% [markdown]
# ### Analysis Pre steps

# %%
def calc_metrics(df, tp1, tp2, tp1_cols, tp2_cols):
    df = df.copy()
    tp1_array = df[tp1_cols].to_numpy()
    tp2_array = df[tp2_cols].to_numpy()

    tp1_total = tp1_array.sum(axis=1)
    tp2_total = tp2_array.sum(axis=1)

    tp1_active = (tp1_array != 0).sum(axis=1)
    tp2_active = (tp2_array != 0).sum(axis=1)

    tp1_avg = np.divide(tp1_total, tp1_active, out=np.zeros_like(tp1_total, dtype=float), where=tp1_active != 0)
    tp2_avg = np.divide(tp2_total, tp2_active, out=np.zeros_like(tp2_total, dtype=float), where=tp2_active != 0)

    def masked_std(arr):
        masked = np.ma.masked_where(arr == 0, arr)
        return masked.std(axis=1, ddof=0)

    tp1_std = masked_std(tp1_array)
    tp2_std = masked_std(tp2_array)

    df[f'{tp1}_Total'] = tp1_total
    df[f'{tp2}_Total'] = tp2_total
    df[f'months_active_{tp1}'] = tp1_active
    df[f'months_active_{tp2}'] = tp2_active
    df[f'avg_act_monthly_{tp1}'] = tp1_avg
    df[f'avg_act_monthly_{tp2}'] = tp2_avg
    df[f'std_dev_{tp1}'] = tp1_std
    df[f'std_dev_{tp2}'] = tp2_std

    return df

# %%
esales_df = calc_metrics(esales_df,tp1, tp2,tp1_cols,tp2_cols)
nonesales_df = calc_metrics(nonesales_df,tp1, tp2,tp1_cols,tp2_cols)

# %%
merged_df = pd.merge(nonesales_df, esales_df, on='global_id', how='outer', suffixes=('_nonesales', '_esales'))
merged_df['flag_gl_id'] = merged_df['flag_gl_id_esales'].combine_first(merged_df['flag_gl_id_nonesales'])
merged_df.drop(columns=['flag_gl_id_esales','flag_gl_id_nonesales'],inplace=True)
merged_df.fillna(0, inplace=True)

usag_df = merged_df

# %%
usag_df
# Out:
#                                     global_id  2023-07_nonesales  \
# 0        000006c3-c93c-b2d1-75a9-d55eff943df8             139.24
# 1        000008fd-b89a-e34f-4cc1-8082184f9627              63.72
# 2        00000d0f-4cff-2258-96e3-37fb60e6dd3f             181.28
# 3        00001b6a-9f19-d466-5b17-498b2134e54b            3294.76
# 4        00003208-43d2-548e-6834-1d26ca82306f               0.00
# ...                                       ...                ...
# 1698982  ffffe0b8-4419-19cc-ebca-e9f175b9a7b3               0.00
# 1698983  ffffebc6-2076-9b23-51c2-5f5293338412               0.00
# 1698984  fffff3c4-c07a-8d6a-8d98-a74f28d06baf               0.00
# 1698985  fffffc8f-cb07-b227-ef84-b2b43815c1ff               0.00
# 1698986  fffffd91-46e2-20ea-7190-1f2775e09e28               0.00
#
#          2023-08_nonesales  2023-09_nonesales  2023-10_nonesales  \
# 0                    76.22               0.00               0.00
# 1                   126.16              97.98              14.09
# 2                    87.38             131.72              66.94
# 3                  1587.71            1871.09             140.99
# 4                     0.00               0.00               0.00
# ...                    ...                ...                ...
# 1698982               0.00               0.00              85.47
# 1698983               0.00               0.00               0.00
# 1698984               0.00               0.00               0.00
# 1698985               0.00               0.00               0.00
# 1698986               0.00               0.00               0.00
#
#          2023-11_nonesales  2023-12_nonesales  2024-01_nonesales  \
# 0                    25.85              59.40               0.00
# 1                   411.39             140.32              48.02
# 2                    89.62             248.63             316.88
# 3                  -130.99               0.00             166.20
# 4                     0.00               0.00               0.00
# ...                    ...                ...                ...
# 1698982               0.00               0.00               0.00
# 1698983               0.00               0.00               0.00
# 1698984               0.00               0.00               0.00
# 1698985               0.00               0.00               0.00
# 1698986               0.00               0.00               0.00
#
#          2024-02_nonesales  2024-03_nonesales  ...  2025-06_esales  \
# 0                    43.83              14.25  ...            0.00
# 1                   150.56              68.61  ...            0.00
# 2                   531.97             621.99  ...          104.00
# 3                  -124.99               0.00  ...            0.00
# 4                     0.00               0.00  ...            0.00
# ...                    ...                ...  ...             ...
# 1698982               0.00               0.00  ...            0.00
# 1698983               0.00               0.00  ...            0.00
# 1698984               0.00               0.00  ...            0.00
# 1698985               0.00               0.00  ...            0.00
# 1698986               0.00               0.00  ...            0.00
#
#          24_jun_12_Total_esales  25_jun_12_Total_esales  \
# 0                          0.00                    0.00
# 1                          0.00                    0.00
# 2                          0.00                  226.26
# 3                       1903.89                    0.00
# 4                          0.00                    0.00
# ...                         ...                     ...
# 1698982                    0.00                    0.00
# 1698983                    0.00                    0.00
# 1698984                    0.00                    0.00
# 1698985                    0.00                    0.00
# 1698986                    0.00                    0.00
#
#          months_active_24_jun_12_esales  months_active_25_jun_12_esales  \
# 0                                  0.00                            0.00
# 1                                  0.00                            0.00
# 2                                  0.00                            2.00
# 3                                  5.00                            0.00
# 4                                  0.00                            0.00
# ...                                 ...                             ...
# 1698982                            0.00                            0.00
# 1698983                            0.00                            0.00
# 1698984                            0.00                            0.00
# 1698985                            0.00                            0.00
# 1698986                            0.00                            0.00
#
#          avg_act_monthly_24_jun_12_esales  avg_act_monthly_25_jun_12_esales  \
# 0                                    0.00                              0.00
# 1                                    0.00                              0.00
# 2                                    0.00                            113.13
# 3                                  380.78                              0.00
# 4                                    0.00                              0.00
# ...                                   ...                               ...
# 1698982                              0.00                              0.00
# 1698983                              0.00                              0.00
# 1698984                              0.00                              0.00
# 1698985                              0.00                              0.00
# 1698986                              0.00                              0.00
#
#          std_dev_24_jun_12_esales  std_dev_25_jun_12_esales  flag_gl_id
# 0                            0.00                      0.00        0.00
# 1                            0.00                      0.00        0.00
# 2                            0.00                      9.13        0.00
# 3                          174.82                      0.00        0.00
# 4                            0.00                      0.00        0.00
# ...                           ...                       ...         ...
# 1698982                      0.00                      0.00        0.00
# 1698983                      0.00                      0.00        0.00
# 1698984                      0.00                      0.00        0.00
# 1698985                      0.00                      0.00        0.00
# 1698986                      0.00                      0.00        0.00
#
# [1698987 rows x 66 columns]

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Distribution analysis

# %%
def assign_segment(df, k, stype, atype, tp1, tp2):
    avg_tp1 = df[f'avg_{atype}_monthly_{tp1}_{stype}']
    avg_tp2 = df[f'avg_{atype}_monthly_{tp2}_{stype}']
    std_tp1 = df[f'std_dev_{tp1}_{stype}']
    months_tp1 = df[f'months_active_{tp1}_{stype}']

    conditions = [
        (avg_tp1 == 0) & (avg_tp2 == 0),
        avg_tp1 == 0,
        avg_tp2 == 0,
        months_tp1 <= 1,
        avg_tp2 < avg_tp1 - k * std_tp1,
        avg_tp2 > avg_tp1 + k * std_tp1
    ]

    choices = [
        "Not in Channel",
        "New",
        "Declining",
        "Unallocated",
        "Declining",
        "Growing"
    ]

    return np.select(conditions, choices, default="Stable")

# %%
stypes = ['esales', 'nonesales']
atypes = ['act']
ks = [1]

for stype in stypes:
    for atype in atypes:
        for k in ks:
            usag_df[f'{tp1}_{tp2}_{atype}_mon_{stype}_sd_{str(k)}_segment'] = assign_segment(usag_df,k, stype, atype, tp1, tp2)
            print(f'{tp1}_{tp2}_{atype}_mon_{stype}_sd_{str(k)}_segment done')
# Out:
# 24_jun_12_25_jun_12_act_mon_esales_sd_1_segment done
# 24_jun_12_25_jun_12_act_mon_nonesales_sd_1_segment done

# %%
usag_segments = usag_df[['global_id',f'{tp1}_{tp2}_act_mon_esales_sd_1_segment',f'{tp1}_{tp2}_act_mon_nonesales_sd_1_segment']]

# %% [markdown]
# ### YoY assign

# %%
def compute_yoy(df, stype, tp1, tp2):
    total_tp1 = df[f'{tp1}_Total_{stype}']
    total_tp2 = df[f'{tp2}_Total_{stype}']
    
    cond1 = (total_tp1 <= 2) & (total_tp2 <= 2)
    cond2 = (total_tp1 <= 2) & (total_tp2 > 2)
    
    conditions = [cond1, cond2]
    choices = [0, 1]

    yoy = np.select(conditions, choices, default=(total_tp2 / total_tp1) - 1)
    
    return yoy

# %%
usag_df[f'{tp1}_{tp2}_esales_yoy'] = compute_yoy(usag_df,'esales', tp1, tp2)
usag_df[f'{tp1}_{tp2}_nonesales_yoy'] = compute_yoy(usag_df,'nonesales', tp1, tp2)

# %% [markdown]
# ## New Data Load

# %%
bucket_bins = [-np.inf,0,0.001,500,1000,2500, 5000, 10000, 25000, np.inf]
buckets = ['<0','0','0-500','500-1000','1000-2500','2500-5000', '5000-10000', '10000-25000', '25000+']

usag_df[f'{tp1}_bucket'] = pd.cut(usag_df[f'{tp1}_Total_nonesales'], bins=bucket_bins, labels=buckets, right=False)

# %% [markdown]
# ## Inc Analysis

# %%
stypes = ['esales', 'nonesales']
atypes = ['act']
ks = [1]

# %%
usag_df[f'{tp1}_bucket'] = usag_df[f'{tp1}_bucket'].astype(str)

# %%
nonesales_buckets = usag_df.groupby([f'{tp1}_bucket'])[[f'{tp1}_Total_nonesales',f'{tp2}_Total_nonesales']].sum().reset_index()
nonesales_buckets['comp_bucket_YoY'] = (nonesales_buckets[f'{tp2}_Total_nonesales']/nonesales_buckets[f'{tp1}_Total_nonesales'])-1
nonesales_buckets = nonesales_buckets[[f'{tp1}_bucket','comp_bucket_YoY']]
usag_df = usag_df.merge(nonesales_buckets,how='left',on=[f'{tp1}_bucket'])

# %%
cust_buckets = usag_df.groupby([f'{tp1}_bucket','flag_gl_id'])['global_id'].count().reset_index()

# %%
rev_buckets = usag_df.groupby([f'{tp1}_bucket','flag_gl_id'])[[f'{tp1}_Total_esales',f'{tp2}_Total_esales',f'{tp1}_Total_nonesales',f'{tp2}_Total_nonesales']].sum().reset_index()

# %%
rev_buckets = rev_buckets.merge(cust_buckets, on=[f'{tp1}_bucket','flag_gl_id'],how='inner')
rev_buckets['esales_yoy'] = (rev_buckets[f'{tp2}_Total_esales']/rev_buckets[f'{tp1}_Total_esales'])-1
rev_buckets['nonesales_yoy'] = (rev_buckets[f'{tp2}_Total_nonesales']/rev_buckets[f'{tp1}_Total_nonesales'])-1

# %%
rev_buckets
# Out:
#    24_jun_12_bucket  flag_gl_id  24_jun_12_Total_esales  \
# 0                 0        0.00              2119108.28
# 1                 0        1.00               199114.22
# 2             0-500        0.00             39453869.11
# 3             0-500        1.00              3310048.28
# 4         1000-2500        0.00            128958136.25
# 5         1000-2500        1.00              9010085.70
# 6       10000-25000        0.00            528188893.71
# 7       10000-25000        1.00             25932145.08
# 8         2500-5000        0.00            189628545.07
# 9         2500-5000        1.00             11946134.40
# 10           25000+        0.00            598440364.91
# 11           25000+        1.00             23831477.43
# 12         500-1000        0.00             44442228.30
# 13         500-1000        1.00              3192727.93
# 14       5000-10000        0.00            297187196.79
# 15       5000-10000        1.00             17266473.55
# 16               <0        0.00             70707692.49
# 17               <0        1.00              2136420.74
#
#     25_jun_12_Total_esales  24_jun_12_Total_nonesales  \
# 0              73149212.81                       0.00
# 1              17237051.06                       0.00
# 2              52649045.06                79538018.14
# 3               3792239.78                13129976.54
# 4             133377849.55               306709314.72
# 5               8316086.80                31511776.62
# 6             519242407.08              1048002589.36
# 7              22633418.36                77544829.34
# 8             186759425.49               412056965.34
# 9              11175507.24                37357376.91
# 10            621067626.17              3280105885.28
# 11             23228342.56               288273959.12
# 12             48808296.41               107372844.61
# 13              3379829.60                13344776.50
# 14            291864231.03               598511449.21
# 15             15330442.20                48386291.86
# 16             61713996.06               -15745666.43
# 17              1418514.13                -1021862.75
#
#     25_jun_12_Total_nonesales  global_id  esales_yoy            nonesales_yoy
# 0                328727902.02     354398       33.52 493486285681185587200.00
# 1                 59206922.91      97006       85.57 219279832200024424448.00
# 2                147687647.62     443116        0.33                     0.86
# 3                  9398091.04      83859        0.15                    -0.28
# 4                322143655.04     189407        0.03                     0.05
# 5                 14478292.36      19715       -0.08                    -0.54
# 6                954919343.89      67457       -0.02                    -0.09
# 7                 44936057.43       5044       -0.13                    -0.42
# 8                400254985.45     115949       -0.02                    -0.03
# 9                 16406037.98      10564       -0.06                    -0.56
# 10              3029405253.33      40347        0.04                    -0.08
# 11               230225093.86       2977       -0.03                    -0.20
# 12               129275358.45     148499        0.10                     0.20
# 13                 6594173.77      18655        0.06                    -0.51
# 14               562936149.80      84769       -0.02                    -0.06
# 15                24618687.75       6927       -0.11                    -0.49
# 16                -2408423.00       8292       -0.13                    -0.85
# 17                  151456.30       2006       -0.34                    -1.15

# %%
rev_buckets.to_excel('revenue buckets summary.xlsx')

# %%
# esales_buckets.to_excel('esales_buckets.xlsx')
nonesales_buckets
# Out:
#   24_jun_12_bucket          comp_bucket_YoY
# 0                0 414398276327985446912.00
# 1            0-500                     0.70
# 2        1000-2500                    -0.00
# 3      10000-25000                    -0.11
# 4        2500-5000                    -0.07
# 5           25000+                    -0.09
# 6         500-1000                     0.13
# 7       5000-10000                    -0.09
# 8               <0                    -0.87

# %%
nonesales_buckets.to_excel('nonesales_buckets_segment.xlsx')

# %%
def compute_increment(df, seg_col, tp1, tp2):
    yoy_col = f'{tp1}_{tp2}_nonesales_yoy'
    bucket_col = f'{tp1}_bucket'
    comp_yoy_col = 'comp_bucket_YoY'

    conditions = [
        df[seg_col] == 'Not in Channel',
        df[bucket_col].isin(['<0', '0'])
    ]
    
    choices = [
        0.0,
        df[yoy_col]
    ]
    
    inc_pct = np.select(conditions, choices, default=df[yoy_col] - df[comp_yoy_col])
    return inc_pct

# %%
seg_col = f'{tp1}_{tp2}_act_mon_nonesales_sd_1_segment'
cust_count = usag_df[(usag_df[seg_col]=='Not in Channel')].shape[0]
cust_count = len(usag_df) - cust_count
cust_count
# Out:
# 1517566

# %%
usag_df[f'{tp1}_{tp2}_nonesales_incremental_pct'] = compute_increment(usag_df,seg_col, tp1, tp2)
usag_df[f'{tp1}_{tp2}_nonesales_incremental_abs'] = usag_df[f'{tp1}_{tp2}_nonesales_incremental_pct'] * usag_df[f'{tp1}_Total_nonesales']
print(usag_df[f'{tp1}_{tp2}_nonesales_incremental_abs'].sum())
# Out:
# -8973866.859999973

# %% [markdown]
# ### Placeholder

# %%
# usag_df['STO__OWNERSHIP_TYPE_CODE'] = usag_df['STO__OWNERSHIP_TYPE_CODE'].astype(str)

# %%
usag_df.to_parquet(f'Outputs/usag_{tp1}_{tp2}_bucket_isocos_pneinc_updated.parquet',index=False)

# %% [markdown]
# ## Post Analysis

# %% [markdown]
# ### Crosstab creation

# %%
segments = ['Unallocated', 'New', 'Growing', 'Stable', 'Declining', 'Not in Channel']
segments
# Out:
# ['Unallocated', 'New', 'Growing', 'Stable', 'Declining', 'Not in Channel']

# %%
def crosstab_func(usag_df,atype,k,tp1,tp2):
    metric_rows = ['# of Customers', 'noneSales_Inc', f'eSales {tp1}', f'eSales {tp2}']
    metric_cols = ['.','..', f'non-eSales {tp1}', f'non-eSales {tp2}']


    row_index = pd.MultiIndex.from_product([segments, metric_rows])
    col_index = pd.MultiIndex.from_product([segments, metric_cols])


    cross_tab = pd.DataFrame(index=row_index, columns=col_index)


    total_nonesales_tp1 = usag_df[f'{tp1}_Total_nonesales'].sum()
    total_nonesales_tp2 = usag_df[f'{tp2}_Total_nonesales'].sum()
    total_esales_tp1 = usag_df[f'{tp1}_Total_esales'].sum()
    total_esales_tp2 = usag_df[f'{tp2}_Total_esales'].sum()

    for e_seg in segments:
        for n_seg in segments:
            subset = usag_df[
                (usag_df[f'{tp1}_{tp2}_{atype}_mon_esales_sd_{str(k)}_segment'] == e_seg) &
                (usag_df[f'{tp1}_{tp2}_{atype}_mon_nonesales_sd_{str(k)}_segment'] == n_seg)
            ]

            num_customers = subset.shape[0]
            esales_tp1 = subset[f'{tp1}_Total_esales'].sum()
            esales_tp2 = subset[f'{tp2}_Total_esales'].sum()
            nonesales_tp1 = subset[f'{tp1}_Total_nonesales'].sum()
            nonesales_tp2 = subset[f'{tp2}_Total_nonesales'].sum()

            nonesales_inc = subset[f'{tp1}_{tp2}_nonesales_incremental_abs'].sum()

            cross_tab.loc[(e_seg, '# of Customers'), (n_seg, '.')] = num_customers
            cross_tab.loc[(e_seg, '# of Customers'), (n_seg, f'non-eSales {tp1}')] = f"{nonesales_tp1:.0f}"
            cross_tab.loc[(e_seg, '# of Customers'), (n_seg, f'non-eSales {tp2}')] = f"{nonesales_tp2:.0f}"
            cross_tab.loc[(e_seg, 'noneSales_Inc'), (n_seg, f'non-eSales {tp1}')] = f"{(nonesales_tp1/total_nonesales_tp1):.2%}"
            cross_tab.loc[(e_seg, 'noneSales_Inc'), (n_seg, f'non-eSales {tp2}')] = f"{(nonesales_tp2/total_nonesales_tp2):.2%}"

            cross_tab.loc[(e_seg, 'noneSales_Inc'), (n_seg, '.')] = f"{nonesales_inc:.0f}"

            cross_tab.loc[(e_seg, f'eSales {tp1}'), (n_seg, '.')] = f"{esales_tp1:.0f}"
            cross_tab.loc[(e_seg, f'eSales {tp2}'), (n_seg, '.')] = f"{esales_tp2:.0f}"
            cross_tab.loc[(e_seg, f'eSales {tp1}'), (n_seg, '..')] = f"{(esales_tp1/total_esales_tp1):.2%}"
            cross_tab.loc[(e_seg, f'eSales {tp2}'), (n_seg, '..')] = f"{(esales_tp2/total_esales_tp2):.2%}"


    return cross_tab

# %%
sheet_dict = {}
for atype in atypes:
    for k in ks:
        sheet_name = f"cross_tab_{tp1}_{tp2}_{atype}_mon_sd_{str(k)}"
        sheet_dict[sheet_name] = crosstab_func(usag_df,atype, k,tp1, tp2)
print("done")
# Out:
# done

# %%
sheet_dict[f'cross_tab_{tp1}_{tp2}_act_mon_sd_1']
# Out:
#                                 Unallocated                              \
#                                           .     .. non-eSales 24_jun_12
# Unallocated    # of Customers           891    NaN               435780
#                noneSales_Inc        3398888    NaN                0.01%
#                eSales 24_jun_12      443063  0.02%                  NaN
#                eSales 25_jun_12     6854879  0.33%                  NaN
# New            # of Customers          1518    NaN               825742
#                noneSales_Inc        3877361    NaN                0.01%
#                eSales 24_jun_12           0  0.00%                  NaN
#                eSales 25_jun_12     4051237  0.19%                  NaN
# Growing        # of Customers           484    NaN                99880
#                noneSales_Inc         724208    NaN                0.00%
#                eSales 24_jun_12      326707  0.02%                  NaN
#                eSales 25_jun_12     2651397  0.13%                  NaN
# Stable         # of Customers          1087    NaN               215817
#                noneSales_Inc        1047810    NaN                0.00%
#                eSales 24_jun_12     1784236  0.09%                  NaN
#                eSales 25_jun_12     2118194  0.10%                  NaN
# Declining      # of Customers           741    NaN               163090
#                noneSales_Inc         148555    NaN                0.00%
#                eSales 24_jun_12      468009  0.02%                  NaN
#                eSales 25_jun_12      155910  0.01%                  NaN
# Not in Channel # of Customers         94607    NaN             21163788
#                noneSales_Inc       34798122    NaN                0.33%
#                eSales 24_jun_12           0  0.00%                  NaN
#                eSales 25_jun_12           0  0.00%                  NaN
#
#                                                            New         \
#                                 non-eSales 25_jun_12         .     ..
# Unallocated    # of Customers                3923478       537    NaN
#                noneSales_Inc                   0.06%         0    NaN
#                eSales 24_jun_12                  NaN    102237  0.01%
#                eSales 25_jun_12                  NaN   1681324  0.08%
# New            # of Customers                4897230     15306    NaN
#                noneSales_Inc                   0.08%         0    NaN
#                eSales 24_jun_12                  NaN         0  0.00%
#                eSales 25_jun_12                  NaN  85136058  4.06%
# Growing        # of Customers                 897973       324    NaN
#                noneSales_Inc                   0.01%         0    NaN
#                eSales 24_jun_12                  NaN    168930  0.01%
#                eSales 25_jun_12                  NaN   1157644  0.06%
# Stable         # of Customers                1385284       628    NaN
#                noneSales_Inc                   0.02%         0    NaN
#                eSales 24_jun_12                  NaN    800552  0.04%
#                eSales 25_jun_12                  NaN    998678  0.05%
# Declining      # of Customers                 381772       505    NaN
#                noneSales_Inc                   0.01%         0    NaN
#                eSales 24_jun_12                  NaN    239903  0.01%
#                eSales 25_jun_12                  NaN     60216  0.00%
# Not in Channel # of Customers               62649653    252644    NaN
#                noneSales_Inc                   1.00%         0    NaN
#                eSales 24_jun_12                  NaN         0  0.00%
#                eSales 25_jun_12                  NaN         0  0.00%
#
#                                                                            \
#                                 non-eSales 24_jun_12 non-eSales 25_jun_12
# Unallocated    # of Customers                      0               461328
#                noneSales_Inc                   0.00%                0.01%
#                eSales 24_jun_12                  NaN                  NaN
#                eSales 25_jun_12                  NaN                  NaN
# New            # of Customers                      0             76572484
#                noneSales_Inc                   0.00%                1.22%
#                eSales 24_jun_12                  NaN                  NaN
#                eSales 25_jun_12                  NaN                  NaN
# Growing        # of Customers                      0               181265
#                noneSales_Inc                   0.00%                0.00%
#                eSales 24_jun_12                  NaN                  NaN
#                eSales 25_jun_12                  NaN                  NaN
# Stable         # of Customers                      0               244961
#                noneSales_Inc                   0.00%                0.00%
#                eSales 24_jun_12                  NaN                  NaN
#                eSales 25_jun_12                  NaN                  NaN
# Declining      # of Customers                      0               169192
#                noneSales_Inc                   0.00%                0.00%
#                eSales 24_jun_12                  NaN                  NaN
#                eSales 25_jun_12                  NaN                  NaN
# Not in Channel # of Customers                      0            310302001
#                noneSales_Inc                   0.00%                4.94%
#                eSales 24_jun_12                  NaN                  NaN
#                eSales 25_jun_12                  NaN                  NaN
#
#                                    Growing         ...               Stable  \
#                                          .     ..  ... non-eSales 24_jun_12
# Unallocated    # of Customers          846    NaN  ...             56016887
#                noneSales_Inc      12884392    NaN  ...                0.89%
#                eSales 24_jun_12     218282  0.01%  ...                  NaN
#                eSales 25_jun_12    3283050  0.16%  ...                  NaN
# New            # of Customers         3071    NaN  ...            166517304
#                noneSales_Inc      38624746    NaN  ...                2.63%
#                eSales 24_jun_12          0  0.00%  ...                  NaN
#                eSales 25_jun_12    9219860  0.44%  ...                  NaN
# Growing        # of Customers         3605    NaN  ...            210621551
#                noneSales_Inc      41292454    NaN  ...                3.33%
#                eSales 24_jun_12   49067647  2.46%  ...                  NaN
#                eSales 25_jun_12  101051559  4.82%  ...                  NaN
# Stable         # of Customers         8308    NaN  ...            752416162
#                noneSales_Inc      82709009    NaN  ...               11.90%
#                eSales 24_jun_12  159871068  8.01%  ...                  NaN
#                eSales 25_jun_12  157401935  7.51%  ...                  NaN
# Declining      # of Customers         2783    NaN  ...            256374921
#                noneSales_Inc      27247517    NaN  ...                4.05%
#                eSales 24_jun_12   28780232  1.44%  ...                  NaN
#                eSales 25_jun_12   14596096  0.70%  ...                  NaN
# Not in Channel # of Customers       137948    NaN  ...           3314269430
#                noneSales_Inc     444474923    NaN  ...               52.40%
#                eSales 24_jun_12          0  0.00%  ...                  NaN
#                eSales 25_jun_12          0  0.00%  ...                  NaN
#
#                                                        Declining         \
#                                 non-eSales 25_jun_12           .     ..
# Unallocated    # of Customers               53251000         692    NaN
#                noneSales_Inc                   0.85%    -4455585    NaN
#                eSales 24_jun_12                  NaN      190569  0.01%
#                eSales 25_jun_12                  NaN     2477958  0.12%
# New            # of Customers              162152513        1478    NaN
#                noneSales_Inc                   2.58%   -10717057    NaN
#                eSales 24_jun_12                  NaN           0  0.00%
#                eSales 25_jun_12                  NaN     4895477  0.23%
# Growing        # of Customers              188686198        1623    NaN
#                noneSales_Inc                   3.01%   -22453630    NaN
#                eSales 24_jun_12                  NaN    18810342  0.94%
#                eSales 25_jun_12                  NaN    41327370  1.97%
# Stable         # of Customers              662435253        5456    NaN
#                noneSales_Inc                  10.55%   -37507605    NaN
#                eSales 24_jun_12                  NaN    66817340  3.35%
#                eSales 25_jun_12                  NaN    62346038  2.98%
# Declining      # of Customers              220672583       11945    NaN
#                noneSales_Inc                   3.51%   -68254895    NaN
#                eSales 24_jun_12                  NaN    77150183  3.87%
#                eSales 25_jun_12                  NaN    14222932  0.68%
# Not in Channel # of Customers             2995167576      340295    NaN
#                noneSales_Inc                  47.70%  -438669014    NaN
#                eSales 24_jun_12                  NaN           0  0.00%
#                eSales 25_jun_12                  NaN           0  0.00%
#
#                                                                            \
#                                 non-eSales 24_jun_12 non-eSales 25_jun_12
# Unallocated    # of Customers               13161360              7615197
#                noneSales_Inc                   0.21%                0.12%
#                eSales 24_jun_12                  NaN                  NaN
#                eSales 25_jun_12                  NaN                  NaN
# New            # of Customers               34201209             20578849
#                noneSales_Inc                   0.54%                0.33%
#                eSales 24_jun_12                  NaN                  NaN
#                eSales 25_jun_12                  NaN                  NaN
# Growing        # of Customers               47067767             20286203
#                noneSales_Inc                   0.74%                0.32%
#                eSales 24_jun_12                  NaN                  NaN
#                eSales 25_jun_12                  NaN                  NaN
# Stable         # of Customers               86296350             41306857
#                noneSales_Inc                   1.36%                0.66%
#                eSales 24_jun_12                  NaN                  NaN
#                eSales 25_jun_12                  NaN                  NaN
# Declining      # of Customers              106912182             30145570
#                noneSales_Inc                   1.69%                0.48%
#                eSales 24_jun_12                  NaN                  NaN
#                eSales 25_jun_12                  NaN                  NaN
# Not in Channel # of Customers              633084062            175922829
#                noneSales_Inc                  10.01%                2.80%
#                eSales 24_jun_12                  NaN                  NaN
#                eSales 25_jun_12                  NaN                  NaN
#
#                                 Not in Channel                              \
#                                              .     .. non-eSales 24_jun_12
# Unallocated    # of Customers              256    NaN                    0
#                noneSales_Inc                 0    NaN                0.00%
#                eSales 24_jun_12          39942  0.00%                  NaN
#                eSales 25_jun_12          89039  0.00%                  NaN
# New            # of Customers             1928    NaN                    0
#                noneSales_Inc                 0    NaN                0.00%
#                eSales 24_jun_12              0  0.00%                  NaN
#                eSales 25_jun_12         931691  0.04%                  NaN
# Growing        # of Customers              116    NaN                    0
#                noneSales_Inc                 0    NaN                0.00%
#                eSales 24_jun_12          43853  0.00%                  NaN
#                eSales 25_jun_12         101119  0.00%                  NaN
# Stable         # of Customers              459    NaN                    0
#                noneSales_Inc                 0    NaN                0.00%
#                eSales 24_jun_12         282183  0.01%                  NaN
#                eSales 25_jun_12         192126  0.01%                  NaN
# Declining      # of Customers             2008    NaN                    0
#                noneSales_Inc                 0    NaN                0.00%
#                eSales 24_jun_12         604150  0.03%                  NaN
#                eSales 25_jun_12           7308  0.00%                  NaN
# Not in Channel # of Customers           176654    NaN                    0
#                noneSales_Inc                 0    NaN                0.00%
#                eSales 24_jun_12              0  0.00%                  NaN
#                eSales 25_jun_12              0  0.00%                  NaN
#
#
#                                 non-eSales 25_jun_12
# Unallocated    # of Customers                      0
#                noneSales_Inc                   0.00%
#                eSales 24_jun_12                  NaN
#                eSales 25_jun_12                  NaN
# New            # of Customers                      0
#                noneSales_Inc                   0.00%
#                eSales 24_jun_12                  NaN
#                eSales 25_jun_12                  NaN
# Growing        # of Customers                      0
#                noneSales_Inc                   0.00%
#                eSales 24_jun_12                  NaN
#                eSales 25_jun_12                  NaN
# Stable         # of Customers                      0
#                noneSales_Inc                   0.00%
#                eSales 24_jun_12                  NaN
#                eSales 25_jun_12                  NaN
# Declining      # of Customers                      0
#                noneSales_Inc                   0.00%
#                eSales 24_jun_12                  NaN
#                eSales 25_jun_12                  NaN
# Not in Channel # of Customers                      0
#                noneSales_Inc                   0.00%
#                eSales 24_jun_12                  NaN
#                eSales 25_jun_12                  NaN
#
# [24 rows x 24 columns]

# %%
with pd.ExcelWriter(f"crosstab_output_bucket_pne_{tp1}_{tp2}.xlsx") as writer:
    for sheet_name, df in sheet_dict.items():
        df.to_excel(writer,sheet_name = sheet_name[:31])

# %% [markdown]
# ### Placeholder

# %% [markdown]
# # Time Level 9 months apr-24 to dec-24

# %%
usag_df_proxy = usag_segments#pd.read_csv(f'usag_{tp1}_{tp2}_bucket_peinc_updated.csv')

# %%
tp_proxy_1 = tp1
tp_proxy_2 = tp2

# %%
# usag_df_proxy.to_csv(f'usag_{tp_proxy_1}_{tp_proxy_2}_peinc_updated.csv')

# %% [markdown]
# ## Time Level Definition

# %%
tp1 = '24_jun_9'
tp2 = '25_jun_9'


tp1_cols = get_month_list(tp1)
tp2_cols = get_month_list(tp2)

# %%
esales_df = esales_df[['global_id','flag_gl_id'] + tp1_cols + tp2_cols]
nonesales_df = nonesales_df[['global_id','flag_gl_id'] + tp1_cols + tp2_cols]

# %% [markdown]
# ## Pre Analysis

# %% [markdown]
# ### Analysis Pre steps

# %%
def calc_metrics(df, tp1, tp2, tp1_cols, tp2_cols):
    df = df.copy()
    tp1_array = df[tp1_cols].to_numpy()
    tp2_array = df[tp2_cols].to_numpy()

    tp1_total = tp1_array.sum(axis=1)
    tp2_total = tp2_array.sum(axis=1)

    tp1_active = (tp1_array != 0).sum(axis=1)
    tp2_active = (tp2_array != 0).sum(axis=1)

    tp1_avg = np.divide(tp1_total, tp1_active, out=np.zeros_like(tp1_total, dtype=float), where=tp1_active != 0)
    tp2_avg = np.divide(tp2_total, tp2_active, out=np.zeros_like(tp2_total, dtype=float), where=tp2_active != 0)

    def masked_std(arr):
        masked = np.ma.masked_where(arr == 0, arr)
        return masked.std(axis=1, ddof=0)

    tp1_std = masked_std(tp1_array)
    tp2_std = masked_std(tp2_array)

    df[f'{tp1}_Total'] = tp1_total
    df[f'{tp2}_Total'] = tp2_total
    df[f'months_active_{tp1}'] = tp1_active
    df[f'months_active_{tp2}'] = tp2_active
    df[f'avg_act_monthly_{tp1}'] = tp1_avg
    df[f'avg_act_monthly_{tp2}'] = tp2_avg
    df[f'std_dev_{tp1}'] = tp1_std
    df[f'std_dev_{tp2}'] = tp2_std

    return df

# %%
esales_df = calc_metrics(esales_df,tp1, tp2,tp1_cols,tp2_cols)
nonesales_df = calc_metrics(nonesales_df,tp1, tp2,tp1_cols,tp2_cols)

# %%
merged_df = pd.merge(nonesales_df, esales_df, on='global_id', how='outer', suffixes=('_nonesales', '_esales'))
merged_df['flag_gl_id'] = merged_df['flag_gl_id_esales'].combine_first(merged_df['flag_gl_id_nonesales'])
merged_df.drop(columns=['flag_gl_id_esales','flag_gl_id_nonesales'],inplace=True)
merged_df.fillna(0, inplace=True)

usag_df = merged_df

# %%
# usag_df.to_csv(f"usag_{tp1}_{tp2}_unflagged.csv")

# %%
# months_2022, months_2023,months_2024,months_2025 = get_year_columns(nonesales_df)
# months = months_2022 + months_2023 + months_2024 + months_2025



# for month in months:
#     usag_df[month] = usag_df[f'{month}_nonesales'] + usag_df[f'{month}_esales']

# # usag_df = usag_df[['global_id'] + months]

# %%
usag_df
# Out:
#                                     global_id  2023-07_nonesales  \
# 0        000006c3-c93c-b2d1-75a9-d55eff943df8             139.24
# 1        000008fd-b89a-e34f-4cc1-8082184f9627              63.72
# 2        00000d0f-4cff-2258-96e3-37fb60e6dd3f             181.28
# 3        00001b6a-9f19-d466-5b17-498b2134e54b            3294.76
# 4        00003208-43d2-548e-6834-1d26ca82306f               0.00
# ...                                       ...                ...
# 1698982  ffffe0b8-4419-19cc-ebca-e9f175b9a7b3               0.00
# 1698983  ffffebc6-2076-9b23-51c2-5f5293338412               0.00
# 1698984  fffff3c4-c07a-8d6a-8d98-a74f28d06baf               0.00
# 1698985  fffffc8f-cb07-b227-ef84-b2b43815c1ff               0.00
# 1698986  fffffd91-46e2-20ea-7190-1f2775e09e28               0.00
#
#          2023-08_nonesales  2023-09_nonesales  2023-10_nonesales  \
# 0                    76.22               0.00               0.00
# 1                   126.16              97.98              14.09
# 2                    87.38             131.72              66.94
# 3                  1587.71            1871.09             140.99
# 4                     0.00               0.00               0.00
# ...                    ...                ...                ...
# 1698982               0.00               0.00              85.47
# 1698983               0.00               0.00               0.00
# 1698984               0.00               0.00               0.00
# 1698985               0.00               0.00               0.00
# 1698986               0.00               0.00               0.00
#
#          2023-11_nonesales  2023-12_nonesales  2024-01_nonesales  \
# 0                    25.85              59.40               0.00
# 1                   411.39             140.32              48.02
# 2                    89.62             248.63             316.88
# 3                  -130.99               0.00             166.20
# 4                     0.00               0.00               0.00
# ...                    ...                ...                ...
# 1698982               0.00               0.00               0.00
# 1698983               0.00               0.00               0.00
# 1698984               0.00               0.00               0.00
# 1698985               0.00               0.00               0.00
# 1698986               0.00               0.00               0.00
#
#          2024-02_nonesales  2024-03_nonesales  ...  2025-03_esales  \
# 0                    43.83              14.25  ...            0.00
# 1                   150.56              68.61  ...            0.00
# 2                   531.97             621.99  ...            0.00
# 3                  -124.99               0.00  ...            0.00
# 4                     0.00               0.00  ...            0.00
# ...                    ...                ...  ...             ...
# 1698982               0.00               0.00  ...            0.00
# 1698983               0.00               0.00  ...            0.00
# 1698984               0.00               0.00  ...            0.00
# 1698985               0.00               0.00  ...            0.00
# 1698986               0.00               0.00  ...            0.00
#
#          24_jun_9_Total_esales  25_jun_9_Total_esales  \
# 0                         0.00                   0.00
# 1                         0.00                   0.00
# 2                         0.00                   0.00
# 3                      1215.23                   0.00
# 4                         0.00                   0.00
# ...                        ...                    ...
# 1698982                   0.00                   0.00
# 1698983                   0.00                   0.00
# 1698984                   0.00                   0.00
# 1698985                   0.00                   0.00
# 1698986                   0.00                   0.00
#
#          months_active_24_jun_9_esales  months_active_25_jun_9_esales  \
# 0                                 0.00                           0.00
# 1                                 0.00                           0.00
# 2                                 0.00                           0.00
# 3                                 3.00                           0.00
# 4                                 0.00                           0.00
# ...                                ...                            ...
# 1698982                           0.00                           0.00
# 1698983                           0.00                           0.00
# 1698984                           0.00                           0.00
# 1698985                           0.00                           0.00
# 1698986                           0.00                           0.00
#
#          avg_act_monthly_24_jun_9_esales  avg_act_monthly_25_jun_9_esales  \
# 0                                   0.00                             0.00
# 1                                   0.00                             0.00
# 2                                   0.00                             0.00
# 3                                 405.08                             0.00
# 4                                   0.00                             0.00
# ...                                  ...                              ...
# 1698982                             0.00                             0.00
# 1698983                             0.00                             0.00
# 1698984                             0.00                             0.00
# 1698985                             0.00                             0.00
# 1698986                             0.00                             0.00
#
#          std_dev_24_jun_9_esales  std_dev_25_jun_9_esales  flag_gl_id
# 0                           0.00                     0.00        0.00
# 1                           0.00                     0.00        0.00
# 2                           0.00                     0.00        0.00
# 3                         204.64                     0.00        0.00
# 4                           0.00                     0.00        0.00
# ...                          ...                      ...         ...
# 1698982                     0.00                     0.00        0.00
# 1698983                     0.00                     0.00        0.00
# 1698984                     0.00                     0.00        0.00
# 1698985                     0.00                     0.00        0.00
# 1698986                     0.00                     0.00        0.00
#
# [1698987 rows x 54 columns]

# %% [markdown]
# ## Analysis

# %% [markdown]
# ### Distribution analysis

# %%
def get_segment(row,k,stype,atype,tp1,tp2):
    # print(f'avg_{atype}_monthly_2022_{stype}')
    if row[f'avg_{atype}_monthly_{tp1}_{stype}'] == 0 and row[f'avg_{atype}_monthly_{tp2}_{stype}'] == 0:
        return "Not in Channel"
    elif row[f'avg_{atype}_monthly_{tp1}_{stype}'] == 0:
        return "New"
    elif row[f'avg_{atype}_monthly_{tp2}_{stype}'] == 0:
        return "Declining"
    elif row[f'months_active_{tp1}_{stype}'] <= 1:
        return "Unallocated"
    elif row[f'avg_{atype}_monthly_{tp2}_{stype}'] < row[f'avg_{atype}_monthly_{tp1}_{stype}'] - k * row[f'std_dev_{tp1}_{stype}']:
        return "Declining"
    elif row[f'avg_{atype}_monthly_{tp2}_{stype}'] > row[f'avg_{atype}_monthly_{tp1}_{stype}'] + k * row[f'std_dev_{tp1}_{stype}']:
        return "Growing"
    else:
        return "Stable"

# %%
stypes = ['esales', 'nonesales']
atypes = ['act']
ks = [1]

# for stype in stypes:
#     for atype in atypes:
#         for k in ks:
#             usag_df[f'{tp1}_{tp2}_{atype}_mon_{stype}_sd_{str(k)}_segment'] = usag_df.apply(lambda row: get_segment(row,k, stype,atype,tp1,tp2), axis=1 )
#             print(f'{tp1}_{tp2}_{atype}_mon_{stype}_sd_{str(k)}_segment done')

# %% [markdown]
# ### YoY assign

# %%
def compute_yoy(df, stype, tp1, tp2):
    total_tp1 = df[f'{tp1}_Total_{stype}']
    total_tp2 = df[f'{tp2}_Total_{stype}']
    
    cond1 = (total_tp1 <= 2) & (total_tp2 <= 2)
    cond2 = (total_tp1 <= 2) & (total_tp2 > 2)
    
    conditions = [cond1, cond2]
    choices = [0, 1]

    yoy = np.select(conditions, choices, default=(total_tp2 / total_tp1) - 1)
    
    return yoy

# %%
usag_df[f'{tp1}_{tp2}_esales_yoy'] = compute_yoy(usag_df,'esales', tp1, tp2)
usag_df[f'{tp1}_{tp2}_nonesales_yoy'] = compute_yoy(usag_df,'nonesales', tp1, tp2)

# %%
# usag_df.to_csv(f"usag_{tp1}_{tp2}_flagged.csv")

# %% [markdown]
# ## Inc Analysis

# %%
# usag_df = pd.read_csv(f"usag_{tp1}_{tp2}_flagged.csv")

stypes = ['esales', 'nonesales']
atypes = ['act']
ks = [1]

# %%
usag_segments
# Out:
#                                     global_id  \
# 0        000006c3-c93c-b2d1-75a9-d55eff943df8
# 1        000008fd-b89a-e34f-4cc1-8082184f9627
# 2        00000d0f-4cff-2258-96e3-37fb60e6dd3f
# 3        00001b6a-9f19-d466-5b17-498b2134e54b
# 4        00003208-43d2-548e-6834-1d26ca82306f
# ...                                       ...
# 1698982  ffffe0b8-4419-19cc-ebca-e9f175b9a7b3
# 1698983  ffffebc6-2076-9b23-51c2-5f5293338412
# 1698984  fffff3c4-c07a-8d6a-8d98-a74f28d06baf
# 1698985  fffffc8f-cb07-b227-ef84-b2b43815c1ff
# 1698986  fffffd91-46e2-20ea-7190-1f2775e09e28
#
#         24_jun_12_25_jun_12_act_mon_esales_sd_1_segment  \
# 0                                        Not in Channel
# 1                                        Not in Channel
# 2                                                   New
# 3                                             Declining
# 4                                        Not in Channel
# ...                                                 ...
# 1698982                                  Not in Channel
# 1698983                                  Not in Channel
# 1698984                                  Not in Channel
# 1698985                                  Not in Channel
# 1698986                                  Not in Channel
#
#         24_jun_12_25_jun_12_act_mon_nonesales_sd_1_segment
# 0                                                  Growing
# 1                                                   Stable
# 2                                                   Stable
# 3                                                   Stable
# 4                                           Not in Channel
# ...                                                    ...
# 1698982                                          Declining
# 1698983                                                New
# 1698984                                                New
# 1698985                                                New
# 1698986                                     Not in Channel
#
# [1698987 rows x 3 columns]

# %%
usag_df_proxy_2 = usag_df_proxy[['global_id',f'{tp_proxy_1}_{tp_proxy_2}_act_mon_esales_sd_1_segment',f'{tp_proxy_1}_{tp_proxy_2}_act_mon_nonesales_sd_1_segment']]

# %%
usag_df=usag_df.merge(usag_df_proxy_2,how='inner',on='global_id')

# %%
bucket_bins = [-np.inf,0,0.001,500,1000,2500, 5000, 10000, 25000, np.inf]
buckets = ['<0','0','0-500','500-1000','1000-2500','2500-5000', '5000-10000', '10000-25000', '25000+']

usag_df[f'{tp1}_bucket'] = pd.cut(usag_df[f'{tp1}_Total_nonesales'], bins=bucket_bins, labels=buckets, right=False)

# %%
usag_df[f'{tp1}_bucket'] = usag_df[f'{tp1}_bucket'].astype(str)

# %%
nonesales_buckets = usag_df.groupby([f'{tp1}_bucket'])[[f'{tp1}_Total_nonesales',f'{tp2}_Total_nonesales']].sum().reset_index()
nonesales_buckets['comp_bucket_YoY'] = (nonesales_buckets[f'{tp2}_Total_nonesales']/nonesales_buckets[f'{tp1}_Total_nonesales'])-1
nonesales_buckets = nonesales_buckets[[f'{tp1}_bucket','comp_bucket_YoY']]
usag_df = usag_df.merge(nonesales_buckets,how='left',on=[f'{tp1}_bucket'])

# %%
# esales_buckets.to_excel('esales_buckets_9months.xlsx')
nonesales_buckets
# Out:
#   24_jun_9_bucket          comp_bucket_YoY
# 0               0 310039595412910571520.00
# 1           0-500                     0.63
# 2       1000-2500                    -0.05
# 3     10000-25000                    -0.13
# 4       2500-5000                    -0.09
# 5          25000+                    -0.10
# 6        500-1000                     0.06
# 7      5000-10000                    -0.11
# 8              <0                    -0.95

# %%
def compute_increment(df, seg_col, tp1, tp2):
    yoy_col = f'{tp1}_{tp2}_nonesales_yoy'
    bucket_col = f'{tp1}_bucket'
    comp_yoy_col = 'comp_bucket_YoY'

    conditions = [
        df[seg_col] == 'Not in Channel',
        df[bucket_col].isin(['<0', '0'])
    ]
    
    choices = [
        0.0,
        df[yoy_col]
    ]
    
    inc_pct = np.select(conditions, choices, default=df[yoy_col] - df[comp_yoy_col])
    return inc_pct

# %%
seg_col = f'{tp_proxy_1}_{tp_proxy_2}_act_mon_nonesales_sd_1_segment'
cust_count = usag_df[(usag_df[seg_col]=='Not in Channel')].shape[0]
cust_count = len(usag_df) - cust_count
cust_count
# Out:
# 1517566

# %%
usag_df[f'{tp1}_{tp2}_nonesales_incremental_pct'] = compute_increment(usag_df,seg_col, tp1, tp2)
usag_df[f'{tp1}_{tp2}_nonesales_incremental_abs'] = usag_df[f'{tp1}_{tp2}_nonesales_incremental_pct'] * usag_df[f'{tp1}_Total_nonesales']
print(usag_df[f'{tp1}_{tp2}_nonesales_incremental_abs'].sum())
# Out:
# -6457498.819994665

# %% [markdown]
# ### Placeholder

# %%
# usag_df['STO__OWNERSHIP_TYPE_CODE'] = usag_df['STO__OWNERSHIP_TYPE_CODE'].astype(str)

# %%
usag_df.to_parquet(f'Outputs/usag_{tp1}_{tp2}_bucket_isocos_pneinc_updated.parquet',index=False)

# %% [markdown]
# ## Post Analysis

# %% [markdown]
# ### Crosstab creation

# %%
segments = ['Unallocated', 'New', 'Growing', 'Stable', 'Declining', 'Not in Channel']
segments
# Out:
# ['Unallocated', 'New', 'Growing', 'Stable', 'Declining', 'Not in Channel']

# %%
def crosstab_func(usag_df,atype,k,tp1,tp2,tp_proxy_1,tp_proxy_2):
    metric_rows = ['# of Customers', 'noneSales_Inc', f'eSales {tp1}', f'eSales {tp2}']
    metric_cols = ['.','..', f'non-eSales {tp1}', f'non-eSales {tp2}']


    row_index = pd.MultiIndex.from_product([segments, metric_rows])
    col_index = pd.MultiIndex.from_product([segments, metric_cols])


    cross_tab = pd.DataFrame(index=row_index, columns=col_index)


    total_nonesales_tp1 = usag_df[f'{tp1}_Total_nonesales'].sum()
    total_nonesales_tp2 = usag_df[f'{tp2}_Total_nonesales'].sum()
    total_esales_tp1 = usag_df[f'{tp1}_Total_esales'].sum()
    total_esales_tp2 = usag_df[f'{tp2}_Total_esales'].sum()

    for e_seg in segments:
        for n_seg in segments:
            subset = usag_df[
                (usag_df[f'{tp_proxy_1}_{tp_proxy_2}_{atype}_mon_esales_sd_{str(k)}_segment'] == e_seg) &
                (usag_df[f'{tp_proxy_1}_{tp_proxy_2}_{atype}_mon_nonesales_sd_{str(k)}_segment'] == n_seg)
            ]

            num_customers = subset.shape[0]
            esales_tp1 = subset[f'{tp1}_Total_esales'].sum()
            esales_tp2 = subset[f'{tp2}_Total_esales'].sum()
            nonesales_tp1 = subset[f'{tp1}_Total_nonesales'].sum()
            nonesales_tp2 = subset[f'{tp2}_Total_nonesales'].sum()

            nonesales_inc = subset[f'{tp1}_{tp2}_nonesales_incremental_abs'].sum()

            cross_tab.loc[(e_seg, '# of Customers'), (n_seg, '.')] = num_customers
            cross_tab.loc[(e_seg, '# of Customers'), (n_seg, f'non-eSales {tp1}')] = f"{nonesales_tp1:.0f}"
            cross_tab.loc[(e_seg, '# of Customers'), (n_seg, f'non-eSales {tp2}')] = f"{nonesales_tp2:.0f}"
            cross_tab.loc[(e_seg, 'noneSales_Inc'), (n_seg, f'non-eSales {tp1}')] = f"{(nonesales_tp1/total_nonesales_tp1):.2%}"
            cross_tab.loc[(e_seg, 'noneSales_Inc'), (n_seg, f'non-eSales {tp2}')] = f"{(nonesales_tp2/total_nonesales_tp2):.2%}"

            cross_tab.loc[(e_seg, 'noneSales_Inc'), (n_seg, '.')] = f"{nonesales_inc:.0f}"

            cross_tab.loc[(e_seg, f'eSales {tp1}'), (n_seg, '.')] = f"{esales_tp1:.0f}"
            cross_tab.loc[(e_seg, f'eSales {tp2}'), (n_seg, '.')] = f"{esales_tp2:.0f}"
            cross_tab.loc[(e_seg, f'eSales {tp1}'), (n_seg, '..')] = f"{(esales_tp1/total_esales_tp1):.2%}"
            cross_tab.loc[(e_seg, f'eSales {tp2}'), (n_seg, '..')] = f"{(esales_tp2/total_esales_tp2):.2%}"


    return cross_tab

# %%
sheet_dict = {}
for atype in atypes:
    for k in ks:
        sheet_name = f"cross_tab_{tp1}_{tp2}_{atype}_mon_sd_{str(k)}"
        sheet_dict[sheet_name] = crosstab_func(usag_df,atype, k,tp1, tp2,tp_proxy_1,tp_proxy_2)
print("done")
# Out:
# done

# %%
sheet_dict[f'cross_tab_{tp1}_{tp2}_act_mon_sd_1']
# Out:
#                                Unallocated                             \
#                                          .     .. non-eSales 24_jun_9
# Unallocated    # of Customers          891    NaN               48203
#                noneSales_Inc        105905    NaN               0.00%
#                eSales 24_jun_9       24794  0.00%                 NaN
#                eSales 25_jun_9     5031178  0.33%                 NaN
# New            # of Customers         1518    NaN              331404
#                noneSales_Inc        314812    NaN               0.01%
#                eSales 24_jun_9         274  0.00%                 NaN
#                eSales 25_jun_9     2206816  0.14%                 NaN
# Growing        # of Customers          484    NaN               45602
#                noneSales_Inc        176437    NaN               0.00%
#                eSales 24_jun_9      157432  0.01%                 NaN
#                eSales 25_jun_9     1790009  0.12%                 NaN
# Stable         # of Customers         1087    NaN               99035
#                noneSales_Inc         60625    NaN               0.00%
#                eSales 24_jun_9     1173490  0.08%                 NaN
#                eSales 25_jun_9     1640751  0.11%                 NaN
# Declining      # of Customers          741    NaN               67600
#                noneSales_Inc         21954    NaN               0.00%
#                eSales 24_jun_9      332510  0.02%                 NaN
#                eSales 25_jun_9      120705  0.01%                 NaN
# Not in Channel # of Customers        94607    NaN            11940043
#                noneSales_Inc       2937183    NaN               0.25%
#                eSales 24_jun_9         122  0.00%                 NaN
#                eSales 25_jun_9         727  0.00%                 NaN
#
#                                                          New         \
#                                non-eSales 25_jun_9         .     ..
# Unallocated    # of Customers              2855520       537    NaN
#                noneSales_Inc                 0.06%         0    NaN
#                eSales 24_jun_9                 NaN     17872  0.00%
#                eSales 25_jun_9                 NaN   1195699  0.08%
# New            # of Customers              3133264     15306    NaN
#                noneSales_Inc                 0.07%     19344    NaN
#                eSales 24_jun_9                 NaN       458  0.00%
#                eSales 25_jun_9                 NaN  40038081  2.59%
# Growing        # of Customers               679778       324    NaN
#                noneSales_Inc                 0.01%         0    NaN
#                eSales 24_jun_9                 NaN    102283  0.01%
#                eSales 25_jun_9                 NaN    802917  0.05%
# Stable         # of Customers              1028721       628    NaN
#                noneSales_Inc                 0.02%        74    NaN
#                eSales 24_jun_9                 NaN    550425  0.04%
#                eSales 25_jun_9                 NaN    744050  0.05%
# Declining      # of Customers               289302       505    NaN
#                noneSales_Inc                 0.01%       185    NaN
#                eSales 24_jun_9                 NaN    185479  0.01%
#                eSales 25_jun_9                 NaN     49281  0.00%
# Not in Channel # of Customers             46332969    252644    NaN
#                noneSales_Inc                 0.99%      8991    NaN
#                eSales 24_jun_9                 NaN       413  0.00%
#                eSales 25_jun_9                 NaN       866  0.00%
#
#                                                                         \
#                                non-eSales 24_jun_9 non-eSales 25_jun_9
# Unallocated    # of Customers                    0              304270
#                noneSales_Inc                 0.00%               0.01%
#                eSales 24_jun_9                 NaN                 NaN
#                eSales 25_jun_9                 NaN                 NaN
# New            # of Customers                  496            42819933
#                noneSales_Inc                 0.00%               0.92%
#                eSales 24_jun_9                 NaN                 NaN
#                eSales 25_jun_9                 NaN                 NaN
# Growing        # of Customers                    0              120072
#                noneSales_Inc                 0.00%               0.00%
#                eSales 24_jun_9                 NaN                 NaN
#                eSales 25_jun_9                 NaN                 NaN
# Stable         # of Customers                  135              192081
#                noneSales_Inc                 0.00%               0.00%
#                eSales 24_jun_9                 NaN                 NaN
#                eSales 25_jun_9                 NaN                 NaN
# Declining      # of Customers                   42              103569
#                noneSales_Inc                 0.00%               0.00%
#                eSales 24_jun_9                 NaN                 NaN
#                eSales 25_jun_9                 NaN                 NaN
# Not in Channel # of Customers                15842           182006022
#                noneSales_Inc                 0.00%               3.90%
#                eSales 24_jun_9                 NaN                 NaN
#                eSales 25_jun_9                 NaN                 NaN
#
#                                   Growing         ...              Stable  \
#                                         .     ..  ... non-eSales 24_jun_9
# Unallocated    # of Customers         846    NaN  ...            41074396
#                noneSales_Inc      9383757    NaN  ...               0.87%
#                eSales 24_jun_9      48026  0.00%  ...                 NaN
#                eSales 25_jun_9    2257899  0.15%  ...                 NaN
# New            # of Customers        3071    NaN  ...           121784255
#                noneSales_Inc     26529985    NaN  ...               2.58%
#                eSales 24_jun_9         23  0.00%  ...                 NaN
#                eSales 25_jun_9    5012031  0.32%  ...                 NaN
# Growing        # of Customers        3605    NaN  ...           155822427
#                noneSales_Inc     28609567    NaN  ...               3.30%
#                eSales 24_jun_9   33626529  2.28%  ...                 NaN
#                eSales 25_jun_9   71370923  4.62%  ...                 NaN
# Stable         # of Customers        8308    NaN  ...           564130380
#                noneSales_Inc     60435207    NaN  ...              11.94%
#                eSales 24_jun_9  117071279  7.93%  ...                 NaN
#                eSales 25_jun_9  118771188  7.69%  ...                 NaN
# Declining      # of Customers        2783    NaN  ...           191615234
#                noneSales_Inc     20790288    NaN  ...               4.05%
#                eSales 24_jun_9   21897738  1.48%  ...                 NaN
#                eSales 25_jun_9   11705290  0.76%  ...                 NaN
# Not in Channel # of Customers      137948    NaN  ...          2463195238
#                noneSales_Inc    322407843    NaN  ...              52.12%
#                eSales 24_jun_9        376  0.00%  ...                 NaN
#                eSales 25_jun_9       1646  0.00%  ...                 NaN
#
#                                                      Declining         \
#                                non-eSales 25_jun_9           .     ..
# Unallocated    # of Customers             40482815         692    NaN
#                noneSales_Inc                 0.87%    -2987127    NaN
#                eSales 24_jun_9                 NaN       40278  0.00%
#                eSales 25_jun_9                 NaN     1812844  0.12%
# New            # of Customers            122526489        1478    NaN
#                noneSales_Inc                 2.63%    -7045645    NaN
#                eSales 24_jun_9                 NaN         202  0.00%
#                eSales 25_jun_9                 NaN     3118069  0.20%
# Growing        # of Customers            143648037        1623    NaN
#                noneSales_Inc                 3.08%   -16806054    NaN
#                eSales 24_jun_9                 NaN    12534301  0.85%
#                eSales 25_jun_9                 NaN    30332068  1.96%
# Stable         # of Customers            500453517        5456    NaN
#                noneSales_Inc                10.73%   -28126619    NaN
#                eSales 24_jun_9                 NaN    48460600  3.28%
#                eSales 25_jun_9                 NaN    48220874  3.12%
# Declining      # of Customers            167977302       11945    NaN
#                noneSales_Inc                 3.60%   -56817955    NaN
#                eSales 24_jun_9                 NaN    65425544  4.43%
#                eSales 25_jun_9                 NaN    11723990  0.76%
# Not in Channel # of Customers           2266809443      340295    NaN
#                noneSales_Inc                48.59%  -352336751    NaN
#                eSales 24_jun_9                 NaN        9190  0.00%
#                eSales 25_jun_9                 NaN           0  0.00%
#
#                                                                         \
#                                non-eSales 24_jun_9 non-eSales 25_jun_9
# Unallocated    # of Customers              9415949             5998896
#                noneSales_Inc                 0.20%               0.13%
#                eSales 24_jun_9                 NaN                 NaN
#                eSales 25_jun_9                 NaN                 NaN
# New            # of Customers             25587758            16412354
#                noneSales_Inc                 0.54%               0.35%
#                eSales 24_jun_9                 NaN                 NaN
#                eSales 25_jun_9                 NaN                 NaN
# Growing        # of Customers             36140836            15977954
#                noneSales_Inc                 0.76%               0.34%
#                eSales 24_jun_9                 NaN                 NaN
#                eSales 25_jun_9                 NaN                 NaN
# Stable         # of Customers             66756925            32976344
#                noneSales_Inc                 1.41%               0.71%
#                eSales 24_jun_9                 NaN                 NaN
#                eSales 25_jun_9                 NaN                 NaN
# Declining      # of Customers             88400527            23861744
#                noneSales_Inc                 1.87%               0.51%
#                eSales 24_jun_9                 NaN                 NaN
#                eSales 25_jun_9                 NaN                 NaN
# Not in Channel # of Customers            508647782           140208844
#                noneSales_Inc                10.76%               3.01%
#                eSales 24_jun_9                 NaN                 NaN
#                eSales 25_jun_9                 NaN                 NaN
#
#                                Not in Channel                             \
#                                             .     .. non-eSales 24_jun_9
# Unallocated    # of Customers             256    NaN                   0
#                noneSales_Inc                0    NaN               0.00%
#                eSales 24_jun_9          19620  0.00%                 NaN
#                eSales 25_jun_9          65338  0.00%                 NaN
# New            # of Customers            1928    NaN                  36
#                noneSales_Inc                0    NaN               0.00%
#                eSales 24_jun_9            112  0.00%                 NaN
#                eSales 25_jun_9         365754  0.02%                 NaN
# Growing        # of Customers             116    NaN                 162
#                noneSales_Inc                0    NaN               0.00%
#                eSales 24_jun_9          29721  0.00%                 NaN
#                eSales 25_jun_9          81578  0.01%                 NaN
# Stable         # of Customers             459    NaN                 166
#                noneSales_Inc                0    NaN               0.00%
#                eSales 24_jun_9         200249  0.01%                 NaN
#                eSales 25_jun_9         150141  0.01%                 NaN
# Declining      # of Customers            2008    NaN                 813
#                noneSales_Inc                0    NaN               0.00%
#                eSales 24_jun_9         559359  0.04%                 NaN
#                eSales 25_jun_9           5569  0.00%                 NaN
# Not in Channel # of Customers          176654    NaN               55792
#                noneSales_Inc                0    NaN               0.00%
#                eSales 24_jun_9           1552  0.00%                 NaN
#                eSales 25_jun_9            907  0.00%                 NaN
#
#
#                                non-eSales 25_jun_9
# Unallocated    # of Customers                    2
#                noneSales_Inc                 0.00%
#                eSales 24_jun_9                 NaN
#                eSales 25_jun_9                 NaN
# New            # of Customers                 1355
#                noneSales_Inc                 0.00%
#                eSales 24_jun_9                 NaN
#                eSales 25_jun_9                 NaN
# Growing        # of Customers                  160
#                noneSales_Inc                 0.00%
#                eSales 24_jun_9                 NaN
#                eSales 25_jun_9                 NaN
# Stable         # of Customers                  282
#                noneSales_Inc                 0.00%
#                eSales 24_jun_9                 NaN
#                eSales 25_jun_9                 NaN
# Declining      # of Customers                  159
#                noneSales_Inc                 0.00%
#                eSales 24_jun_9                 NaN
#                eSales 25_jun_9                 NaN
# Not in Channel # of Customers                51362
#                noneSales_Inc                 0.00%
#                eSales 24_jun_9                 NaN
#                eSales 25_jun_9                 NaN
#
# [24 rows x 24 columns]

# %%
with pd.ExcelWriter(f"crosstab_output_bucket_pne_{tp1}_{tp2}.xlsx") as writer:
    for sheet_name, df in sheet_dict.items():
        df.to_excel(writer,sheet_name = sheet_name[:31])

# %% [markdown]
# ### Placeholder
